# %% [markdown]
# # Visualization

# %% [markdown]
# In this notebook we will create some visualizations about the gathered data, the model using obtained parameters and ultimatively bond prices. We import previously defined functionalities or define them once again if not possible otherwise.

# %%
# We import matplotlib.pyplot, a well known library for visualization purposes
import matplotlib.pyplot as plt

# This line is specifically needed for jupyter notebooks to show the plots underneath each Code cell. In .py this will not be used.
# %matplotlib inline

# %%
#TODO: Here we should do the plots in plot_sto.py and plot_deter.py with first using the fit.py functions (or directly defining the parameters resulting) for the
# csv data: DFF_clean.csv, SOFR_clean.csv and SR.csv (combined them see more in Data_prep.ipynb). Explain what is used for the plots 
# what they show and talk about model properties.
